# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
shape = (2, 128, 128)
data = np.load('../../Dataset/CleanDataset.npy')
train = data[:int(len(data) * 0.8), :]

for i in range(1, 10000, 1000):
    test_input = train[i, :128]
    plt.plot(test_input)
    plt.show()
